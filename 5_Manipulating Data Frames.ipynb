# %%
"""
list = [1, "Hello", 3.4]
tuple = ('p','e','r','m','i','t')
dict = {1: 'apple', 2: 'ball'}
set = {1.0, "Hello", (1, 2, 3)}
"""
# Out:
# '\nlist = [1, "Hello", 3.4]\ntuple = (\'p\',\'e\',\'r\',\'m\',\'i\',\'t\')\ndict = {1: \'apple\', 2: \'ball\'}\nset = {1.0, "Hello", (1, 2, 3)}\n'

# %%
import pandas as pd

# %%
ls
# Out:
#  Volume in drive C is Windows8_OS
#  Volume Serial Number is 08E3-7261
#
#  Directory of C:\Users\user\Desktop\Self Learning\Jupyter Codes\Data
#
# 28/01/2019  11:17 AM    <DIR>          .
# 28/01/2019  11:17 AM    <DIR>          ..
# 23/01/2019  05:13 PM        55,052,764 311-service-requests.csv
# 17/02/2018  06:01 PM            13,807 bikes.csv
# 04/01/2019  08:31 PM            17,345 mpg.csv
# 25/01/2019  01:32 PM               312 mpg_head.csv
# 03/05/2018  09:57 PM         8,321,722 sub-est2016_all.csv
# 15/01/2019  11:37 AM            14,505 wic.xlsx
# 15/01/2019  11:37 AM           385,024 WICAgencies2013ytd.xls
# 15/01/2019  11:32 AM             2,023 wine_reviews.csv
# 27/11/2017  05:08 PM        49,784,334 winemag-data_first150k.csv
# 27/11/2017  05:08 PM        52,908,706 winemag-data-130k-v2.csv
#               10 File(s)    166,500,542 bytes
#                2 Dir(s)  29,660,704,768 bytes free

# %%
reviews=pd.read_csv("Data//winemag-data_first150k.csv",delimiter=",",index_col=0)

# %%
reviews.head(2)
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
#
#       region_1 region_2             variety                   winery
# 0  Napa Valley     Napa  Cabernet Sauvignon                    Heitz
# 1         Toro      NaN       Tinta de Toro  Bodega Carmen Rodríguez

# %%
#reviews.country.unique()
reviews["country"].unique()
# Out:
# array(['US', 'Spain', 'France', 'Italy', 'New Zealand', 'Bulgaria',
#        'Argentina', 'Australia', 'Portugal', 'Israel', 'South Africa',
#        'Greece', 'Chile', 'Morocco', 'Romania', 'Germany', 'Canada',
#        'Moldova', 'Hungary', 'Austria', 'Croatia', 'Slovenia', nan,
#        'India', 'Turkey', 'Macedonia', 'Lebanon', 'Serbia', 'Uruguay',
#        'Switzerland', 'Albania', 'Bosnia and Herzegovina', 'Brazil',
#        'Cyprus', 'Lithuania', 'Japan', 'China', 'South Korea', 'Ukraine',
#        'England', 'Mexico', 'Georgia', 'Montenegro', 'Luxembourg',
#        'Slovakia', 'Czech Republic', 'Egypt', 'Tunisia', 'US-France'],
#       dtype=object)

# %%
reviews.count()#counts the number of values in each column
# Out:
# country        150925
# description    150930
# designation    105195
# points         150930
# price          137235
# province       150925
# region_1       125870
# region_2        60953
# variety        150930
# winery         150930
# dtype: int64

# %%
reviews["country"].count()
# Out:
# 150925

# %%
reviews.shape
# Out:
# (150930, 10)

# %%
reviews.loc[(reviews.points>=90)]
# Out:
#             country                                        description  \
# 0                US  This tremendous 100% varietal wine hails from ...
# 1             Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2                US  Mac Watson honors the memory of a wine once ma...
# 3                US  This spent 20 months in 30% new French oak, an...
# 4            France  This is the top wine from La Bégude, named aft...
# 5             Spain  Deep, dense and pure from the opening bell, th...
# 6             Spain  Slightly gritty black-fruit aromas include a s...
# 7             Spain  Lush cedary black-fruit aromas are luxe and of...
# 8                US  This re-named vineyard was formerly bottled as...
# 9                US  The producer sources from two blocks of the vi...
# 10            Italy  Elegance, complexity and structure come togeth...
# 11               US  From 18-year-old vines, this supple well-balan...
# ...

# %%
reviews.points.sum()
# Out:
# 13264999

# %%
reviews.points.min()
# Out:
# 80

# %%
reviews.points.max()
# Out:
# 100

# %%
reviews.points.mean()
# Out:
# 87.8884184721394

# %%
reviews.points.median()
# Out:
# 88.0

# %%
#reviews.groupby("country").mean()
#reviews.groupby("country").mean()[["price"]]#return a data structure
reviews.groupby("country").mean()["price"]#return a series
# Out:
# country
# Albania                   20.000000
# Argentina                 20.794881
# Australia                 31.258480
# Austria                   31.192106
# Bosnia and Herzegovina    12.750000
# Brazil                    19.920000
# Bulgaria                  11.545455
# Canada                    34.628866
# Chile                     19.344780
# China                     20.333333
# Croatia                   23.108434
# Cyprus                    15.483871
# Czech Republic            18.000000
# Egypt                           NaN
# England                   47.500000
# France                    45.619885
# Georgia                   18.581395
# Germany                   39.011078
# Greece                    21.747706
# Hungary                   44.204348
# India                     13.875000
# Israel                    31.304918
# Italy                     37.547913
# Japan                     24.000000
# Lebanon                   25.432432
# Lithuania                 10.000000
# ...

# %% [markdown]
# .groupby(col).count() should be used when you want to find the frequency of valid values present in columns with respect to specified col.-----applied to dataframe
#
# .value_counts() should be used to find the frequencies of a series.-----applied to Series

# %%
#reviews.groupby("country").count()#which country has the most reviewers
reviews.country.value_counts()
# Out:
# US                        62397
# Italy                     23478
# France                    21098
# Spain                      8268
# Chile                      5816
# Argentina                  5631
# Portugal                   5322
# Australia                  4957
# New Zealand                3320
# Austria                    3057
# Germany                    2452
# South Africa               2258
# Greece                      884
# Israel                      630
# Hungary                     231
# Canada                      196
# Romania                     139
# Slovenia                     94
# Uruguay                      92
# Croatia                      89
# Bulgaria                     77
# Moldova                      71
# Mexico                       63
# Turkey                       52
# Georgia                      43
# Lebanon                      37
# Cyprus                       31
# Brazil                       25
# Macedonia                    16
# ...

# %%
#read both Australia and New Zealand, where points>=95
top_oceania_wines = reviews.loc[(reviews.country.isin(['Australia', 'New Zealand'])) & (reviews.points >= 95)]
top_oceania_wines
# Out:
#           country                                        description  \
# 2148    Australia  Full-bodied and plush yet vibrant and imbued w...
# 2458    Australia  This is a top example of the classic Australia...
# 3033    Australia  This Cabernet equivalent to Grange has explode...
# 3044    Australia  From vines planted in 1912, this has been an i...
# 3047    Australia  This is a throwback to those brash, flavor-exu...
# 3048    Australia  This rich, opulent wine carries its massive oa...
# 10505   Australia  This has all the size and weight you've come t...
# 10508   Australia  This shows the strength of the 2010 vintage in...
# 10509   Australia  This is dark and concentrated, as you might ex...
# 10512   Australia  Winemaker Dave Powell is no longer with Torbre...
# 10517   Australia  RWT (unromantically derived from “Red Wine Tri...
# 10522   Australia  With aromas and flavors that range widely from...
# 10528   Australia  This is likely the most ageworthy Shiraz winem...
# ...

# %%
#the median of AU and NZ points
#top_oceania_wines.points.median()#use Tab key to achieve faster typing
top_oceania_wines["points"].median()
# Out:
# 96.0

# %%
Countrynames=reviews.country.unique()

# %%
Countrynames
# Out:
# array(['US', 'Spain', 'France', 'Italy', 'New Zealand', 'Bulgaria',
#        'Argentina', 'Australia', 'Portugal', 'Israel', 'South Africa',
#        'Greece', 'Chile', 'Morocco', 'Romania', 'Germany', 'Canada',
#        'Moldova', 'Hungary', 'Austria', 'Croatia', 'Slovenia', nan,
#        'India', 'Turkey', 'Macedonia', 'Lebanon', 'Serbia', 'Uruguay',
#        'Switzerland', 'Albania', 'Bosnia and Herzegovina', 'Brazil',
#        'Cyprus', 'Lithuania', 'Japan', 'China', 'South Korea', 'Ukraine',
#        'England', 'Mexico', 'Georgia', 'Montenegro', 'Luxembourg',
#        'Slovakia', 'Czech Republic', 'Egypt', 'Tunisia', 'US-France'],
#       dtype=object)

# %%
reviews_0=reviews.iloc[0:60,:]

# %%
import numpy as np

# %%
add=pd.Series(np.random.randn(49))
add.head()
# Out:
# 0   -0.398197
# 1   -0.055314
# 2   -0.653288
# 3   -2.056280
# 4    1.008358
# dtype: float64

# %%
Reviews_add=pd.DataFrame({"country":Countrynames,"new_columns":add})
Reviews_add_0=Reviews_add.append(pd.DataFrame([["Wierd Name",1]],columns=Reviews_add.columns)).reset_index(drop=1)
#Reviews_add_0

# %%
#?pd.DataFrame.append

# %%
Reviews_add_0.shape
# Out:
# (50, 2)

# %%
reviews_0.shape
# Out:
# (60, 10)

# %%
# ?pd.DataFrame.merge()

# %%
reviews_0.merge(Reviews_add_0,how="left",on="country")#based on "country" column to merge
# Out:
#         country                                        description  \
# 0            US  This tremendous 100% varietal wine hails from ...
# 1         Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2            US  Mac Watson honors the memory of a wine once ma...
# 3            US  This spent 20 months in 30% new French oak, an...
# 4        France  This is the top wine from La Bégude, named aft...
# 5         Spain  Deep, dense and pure from the opening bell, th...
# 6         Spain  Slightly gritty black-fruit aromas include a s...
# 7         Spain  Lush cedary black-fruit aromas are luxe and of...
# 8            US  This re-named vineyard was formerly bottled as...
# 9            US  The producer sources from two blocks of the vi...
# 10        Italy  Elegance, complexity and structure come togeth...
# 11           US  From 18-year-old vines, this supple well-balan...
# 12           US  A standout even in this terrific lineup of 201...
# ...

# %%
reviews.sort_values("points",ascending=False).head()#after sorting, the index goes unordered
# Out:
#           country                                        description  \
# 137099         US  Tasted in a flight of great and famous Napa wi...
# 19354          US  In a stunning lineup of Cayuse Syrahs, the En ...
# 84035   Australia  Not a Cellar Selection in the traditional sens...
# 84034          US  In a stunning lineup of Cayuse Syrahs, the En ...
# 122767         US  A spectacular Pinot Noir, but a very young one...
#
#                    designation  points  price    province  \
# 137099                     NaN     100  200.0  California
# 19354   En Chamberlin Vineyard     100   65.0      Oregon
# 84035                     Rare     100  300.0    Victoria
# 84034   En Chamberlin Vineyard     100   65.0      Oregon
# 122767  Litton Estate Vineyard     100  100.0  California
#
#                        region_1      region_2             variety  \
# 137099              Napa Valley          Napa  Cabernet Sauvignon
# ...

# %%
reviews.sort_values("points",ascending=False).reset_index(drop=1).head()
# Out:
#      country                                        description  \
# 0         US  Tasted in a flight of great and famous Napa wi...
# 1         US  In a stunning lineup of Cayuse Syrahs, the En ...
# 2  Australia  Not a Cellar Selection in the traditional sens...
# 3         US  In a stunning lineup of Cayuse Syrahs, the En ...
# 4         US  A spectacular Pinot Noir, but a very young one...
#
#               designation  points  price    province                 region_1  \
# 0                     NaN     100  200.0  California              Napa Valley
# 1  En Chamberlin Vineyard     100   65.0      Oregon  Walla Walla Valley (OR)
# 2                    Rare     100  300.0    Victoria               Rutherglen
# 3  En Chamberlin Vineyard     100   65.0      Oregon  Walla Walla Valley (OR)
# 4  Litton Estate Vineyard     100  100.0  California     Russian River Valley
#
#        region_2             variety                       winery
# ...

# %% [markdown]
# ------------------------------------------------------------------------------------------------------
# Second Data Set

# %%
reviews_2=pd.read_csv("Data//winemag-data-130k-v2.csv",index_col=0)

# %%
reviews_2.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %% [markdown]
# Create a series,where the groupby() is the index;

# %%
reviews_written=reviews_2.groupby("taster_twitter_handle").size()

# %%
reviews_written
# Out:
# taster_twitter_handle
# @AnneInVino          3685
# @JoeCz               5147
# @bkfiona               27
# @gordone_cellars     4177
# @kerinokeefe        10776
# @laurbuzz            1835
# @mattkettmann        6332
# @paulgwine           9532
# @suskostrzewa        1085
# @vboone              9537
# @vossroger          25514
# @wawinereport        4966
# @wineschach         15134
# @winewchristina         6
# @worldwineguys       1005
# dtype: int64

# %%
best_rating_per_price =reviews_2.groupby("price")["points"].max().sort_index(ascending=1)#sort the index

best_rating_per_price.head()
# Out:
# price
# 4.0    86
# 5.0    87
# 6.0    88
# 7.0    91
# 8.0    91
# Name: points, dtype: int64

# %% [markdown]
# Create Dataframe by .agg

# %%
price_extremes = reviews_2.groupby('variety').price.agg([min, max])
#price_extremes

# %%
sorted_varieties = price_extremes.sort_values(by=["min","max"],ascending=False)
#sorted_varieties

# %%
reviewer_mean_ratings = reviews_2.groupby("taster_name").points.mean()
reviewer_mean_ratings
# Out:
# taster_name
# Alexander Peartree    85.855422
# Anna Lee C. Iijima    88.415629
# Anne Krebiehl MW      90.562551
# Carrie Dykes          86.395683
# Christina Pickard     87.833333
# Fiona Adams           86.888889
# Jeff Jenssen          88.319756
# Jim Gordon            88.626287
# Joe Czerwinski        88.536235
# Kerin O’Keefe         88.867947
# Lauren Buzzeo         87.739510
# Matt Kettmann         90.008686
# Michael Schachner     86.907493
# Mike DeSimone         89.101167
# Paul Gregutt          89.082564
# Roger Voss            88.708003
# Sean P. Sullivan      88.755739
# Susan Kostrzewa       86.609217
# Virginie Boone        89.213379
# Name: points, dtype: float64

# %%
country_variety_counts = reviews_2.groupby(["country","variety"]).size().sort_values(ascending=False)
country_variety_counts
# Out:
# country     variety
# US          Pinot Noir                    9885
#             Cabernet Sauvignon            7315
#             Chardonnay                    6801
# France      Bordeaux-style Red Blend      4725
# Italy       Red Blend                     3624
# US          Syrah                         3244
#             Red Blend                     2972
# France      Chardonnay                    2808
# Italy       Nebbiolo                      2736
# US          Zinfandel                     2711
# Portugal    Portuguese Red                2466
# US          Merlot                        2311
# Italy       Sangiovese                    2265
# US          Sauvignon Blanc               2163
# France      Pinot Noir                    1966
#             Rosé                          1923
# US          Bordeaux-style Red Blend      1824
# Germany     Riesling                      1790
# US          Riesling                      1753
# ...

# %%
#reviews_2[6:]# DataFrame in Python only applicable to rows

# %%
reviews_2.points.dtype
# Out:
# dtype('int64')

# %%
type(reviews_2.points)
# Out:
# pandas.core.series.Series

# %%
reviews_2.points.astype(str).head()
# Out:
# 0    87
# 1    87
# 2    87
# 3    87
# 4    87
# Name: points, dtype: object

# %%
str(reviews_2.points)
# Out:
# '0         87\n1         87\n2         87\n3         87\n4         87\n5         87\n6         87\n7         87\n8         87\n9         87\n10        87\n11        87\n12        87\n13        87\n14        87\n15        87\n16        87\n17        87\n18        87\n19        87\n20        87\n21        87\n22        87\n23        87\n24        87\n25        87\n26        87\n27        87\n28        87\n29        86\n          ..\n129941    90\n129942    90\n129943    90\n129944    90\n129945    90\n129946    90\n129947    90\n129948    90\n129949    90\n129950    90\n129951    90\n129952    90\n129953    90\n129954    90\n129955    90\n129956    90\n129957    90\n129958    90\n129959    90\n129960    90\n129961    90\n129962    90\n129963    90\n129964    90\n129965    90\n129966    90\n129967    90\n129968    90\n129969    90\n129970    90\nName: points, Length: 129971, dtype: int64'

# %%
reviews_2.price.isnull().count()
# Out:
# 129971

# %%
reviews_2.price.isnull().sum()
# Out:
# 8996

# %% [markdown]
# Very useful code

# %%
reviews_2.region_1.fillna("unknown").value_counts().sort_values(ascending=False)
# Out:
# unknown                                   21247
# Napa Valley                                4480
# Columbia Valley (WA)                       4124
# Russian River Valley                       3091
# California                                 2629
# Paso Robles                                2350
# Mendoza                                    2301
# Willamette Valley                          2301
# Alsace                                     2163
# Champagne                                  1613
# Barolo                                     1599
# Finger Lakes                               1565
# Sonoma Coast                               1474
# Brunello di Montalcino                     1470
# Rioja                                      1469
# Sonoma County                              1246
# Toscana                                    1197
# Walla Walla Valley (WA)                    1066
# Chianti Classico                           1062
# Santa Barbara County                       1000
# ...

# %%
reviews_2.rename(columns=dict(region_1="region",region_2="locale"))
# Out:
#             country                                        description  \
# 0             Italy  Aromas include tropical fruit, broom, brimston...
# 1          Portugal  This is ripe and fruity, a wine that is smooth...
# 2                US  Tart and snappy, the flavors of lime flesh and...
# 3                US  Pineapple rind, lemon pith and orange blossom ...
# 4                US  Much like the regular bottling from 2012, this...
# 5             Spain  Blackberry and raspberry aromas show a typical...
# 6             Italy  Here's a bright, informal red that opens with ...
# 7            France  This dry and restrained wine offers spice in p...
# 8           Germany  Savory dried thyme notes accent sunnier flavor...
# 9            France  This has great depth of flavor with its fresh ...
# 10               US  Soft, supple plum envelopes an oaky structure ...
# 11           France  This is a dry wine, very spicy, with a tight, ...
# ...

# %%
# ?pd.DataFrame.rename_axis()

# %%
reviews_2.rename_axis("wines",axis="columns")
reviews.rename_axis("wines",axis="columns")
# Out:
# wines       country                                        description  \
# 0                US  This tremendous 100% varietal wine hails from ...
# 1             Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2                US  Mac Watson honors the memory of a wine once ma...
# 3                US  This spent 20 months in 30% new French oak, an...
# 4            France  This is the top wine from La Bégude, named aft...
# 5             Spain  Deep, dense and pure from the opening bell, th...
# 6             Spain  Slightly gritty black-fruit aromas include a s...
# 7             Spain  Lush cedary black-fruit aromas are luxe and of...
# 8                US  This re-named vineyard was formerly bottled as...
# 9                US  The producer sources from two blocks of the vi...
# 10            Italy  Elegance, complexity and structure come togeth...
# 11               US  From 18-year-old vines, this supple well-balan...
# ...

# %%
reviews_3=pd.concat([reviews,reviews_2])
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   """Entry point for launching an IPython kernel.

# %%
reviews_3.count()
# Out:
# country                  280833
# description              280901
# designation              197701
# points                   280901
# price                    258210
# province                 280833
# region_1                 234594
# region_2                 111464
# taster_name              103727
# taster_twitter_handle     98758
# title                    129971
# variety                  280900
# winery                   280901
# dtype: int64

# %%
reviews.count()
# Out:
# country        150925
# description    150930
# designation    105195
# points         150930
# price          137235
# province       150925
# region_1       125870
# region_2        60953
# variety        150930
# winery         150930
# dtype: int64

# %%
Reviews_4=reviews.set_index("wines").join(reviews_2.set_index("wines"))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'wines'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-92-a9fb18aceeb8> in <module>()
# ...
