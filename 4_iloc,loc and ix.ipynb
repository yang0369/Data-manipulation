# %%
import pandas as pd

# %%
ls
# Out:
#  Volume in drive C is Windows8_OS
#  Volume Serial Number is 08E3-7261
#
#  Directory of C:\Users\user\Desktop\Self Learning\Jupyter Codes\Data
#
# 02/02/2019  10:42 AM    <DIR>          .
# 02/02/2019  10:42 AM    <DIR>          ..
# 23/01/2019  05:13 PM        55,052,764 311-service-requests.csv
# 17/02/2018  06:01 PM            13,807 bikes.csv
# 01/02/2019  04:01 PM           451,405 Kaggle_Project_1_test.csv
# 01/02/2019  04:02 PM           460,676 Kaggle_Project_1_train.csv
# 04/01/2019  08:31 PM            17,345 mpg.csv
# 25/01/2019  01:32 PM               312 mpg_head.csv
# 03/05/2018  09:57 PM         8,321,722 sub-est2016_all.csv
# 15/01/2019  11:37 AM            14,505 wic.xlsx
# 15/01/2019  11:37 AM           385,024 WICAgencies2013ytd.xls
# 15/01/2019  11:32 AM             2,023 wine_reviews.csv
# 27/11/2017  05:08 PM        49,784,334 winemag-data_first150k.csv
# 27/11/2017  05:08 PM        52,908,706 winemag-data-130k-v2.csv
# ...

# %%
data=pd.read_csv("bikes.csv",delimiter=";",index_col=0)
data.head()
# Out:
#             Berri 1  Br?beuf (donn?es non disponibles)  C?te-Sainte-Catherine  \
# Date
# 01/01/2012       35                                NaN                      0
# 02/01/2012       83                                NaN                      1
# 03/01/2012      135                                NaN                      2
# 04/01/2012      144                                NaN                      1
# 05/01/2012      197                                NaN                      2
#
#             Maisonneuve 1  Maisonneuve 2  du Parc  Pierre-Dupuy  Rachel1  \
# Date
# 01/01/2012             38             51       26            10       16
# 02/01/2012             68            153       53             6       43
# 03/01/2012            104            248       89             3       58
# 04/01/2012            116            318      111             8       61
# 05/01/2012            124            330       97            13       95
#
# ...

# %% [markdown]
# iloc:integer position based (from 0 to length-1 of the axis)

# %%
data.iloc[0] #select the first row of the DataFrame
# Out:
# Berri 1                                35.0
# Br?beuf (donn?es non disponibles)       NaN
# C?te-Sainte-Catherine                   0.0
# Maisonneuve 1                          38.0
# Maisonneuve 2                          51.0
# du Parc                                26.0
# Pierre-Dupuy                           10.0
# Rachel1                                16.0
# St-Urbain (donn?es non disponibles)     NaN
# Name: 01/01/2012, dtype: float64

# %%
data.iloc[0,0] #select first row,first column
# Out:
# 35

# %%
data.iloc[0,:5] #select first row,first 5 columns
# Out:
# Berri 1                              35.0
# Br?beuf (donn?es non disponibles)     NaN
# C?te-Sainte-Catherine                 0.0
# Maisonneuve 1                        38.0
# Maisonneuve 2                        51.0
# Name: 01/01/2012, dtype: float64

# %% [markdown]
# loc:index based selection

# %%
data.loc["01/01/2012"]
# Out:
# Berri 1                                35.0
# Br?beuf (donn?es non disponibles)       NaN
# C?te-Sainte-Catherine                   0.0
# Maisonneuve 1                          38.0
# Maisonneuve 2                          51.0
# du Parc                                26.0
# Pierre-Dupuy                           10.0
# Rachel1                                16.0
# St-Urbain (donn?es non disponibles)     NaN
# Name: 01/01/2012, dtype: float64

# %%
data.loc[["04/01/2012","05/01/2012"],["Maisonneuve 1","Rachel1"]]
# Out:
#             Maisonneuve 1  Rachel1
# Date
# 04/01/2012            116       61
# 05/01/2012            124       95

# %%
data.loc[(data.Rachel1>60) | (data["Maisonneuve 1"]<100)]
# Out:
#             Berri 1  Br?beuf (donn?es non disponibles)  C?te-Sainte-Catherine  \
# Date
# 01/01/2012       35                                NaN                      0
# 02/01/2012       83                                NaN                      1
# 04/01/2012      144                                NaN                      1
# 05/01/2012      197                                NaN                      2
# 06/01/2012      146                                NaN                      0
# 07/01/2012       98                                NaN                      2
# 08/01/2012       95                                NaN                      1
# 09/01/2012      244                                NaN                      2
# 10/01/2012      397                                NaN                      3
# 11/01/2012      273                                NaN                      0
# 12/01/2012      157                                NaN                      1
# ...

# %%
data.ix[0]==data.ix["01/01/2012"]
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# Berri 1                                 True
# Br?beuf (donn?es non disponibles)      False
# C?te-Sainte-Catherine                   True
# Maisonneuve 1                           True
# Maisonneuve 2                           True
# du Parc                                 True
# Pierre-Dupuy                            True
# Rachel1                                 True
# St-Urbain (donn?es non disponibles)    False
# Name: 01/01/2012, dtype: bool
